# %%
# 209

def get_min_sub_array(nums, target):
    # first check edge case
    # should communiate edge cases
    # you can run and use print statement, but ask first
    
    # Good
    # start with brute force
    # explain your optimization
    
    # Bad
    # Codestyle
    
    if not nums: # 
        return -1 # ask what to return for edge case
    
    min_length = len(nums)+1
    
    left,right = 0,0 # use left vs right instead of front or back
    
    curr_sum = 0
    """
    for num in nums:
        
        right += 1
        
        curr_sum += num
        
        while curr_sum >= target: # index
            
            if left >= len(nums): # when doing while loop, becareful of IndexError
                break
            
            
            min_length = min((right-left),min_length) # 2
            
            curr_sum -= nums[left]
            
            left +=1

    """
    for left in range(len(nums)):
        while right < len(nums) and curr_sum < target:
            curr_sum += nums[right]
            right += 1
            
        if curr_sum >= target:
            min_length = min((right-left),min_length) 
            
        curr_sum -= nums[left]
            
        
    if min_length == len(nums) + 1:
        return -1

    return min_length





if __name__ == "__main__":
    
    nums = [2,3,4,3,4,7,2]
    #       | |
    # [4,7], 2
    
    target = 10
    
    output = get_min_sub_array(nums, target)
    
    print(output)
